# %%
import pandas as pd
import numpy as np

b_seri=pd.Series({"one":1,"two":2,"three":3,"four":4,"five":5})
print(b_seri[2:4])
print(b_seri["one":"four"])
# Out:
# three    3
# four     4
# dtype: int64
# one      1
# two      2
# three    3
# four     4
# dtype: int64

# %%
fr=pd.DataFrame(data=np.random.random((400,3)),index=np.arange(400),columns=["A","B","C"])
sum(fr["A"][0:])
# Out:
# 208.6451718086408

# %%
yas=pd.Series({"A":25,"B":26,"C":27,"D":58},name="Yas")
boy=pd.Series({"A":170,"B":180,"C":190},name="kilo")
tx=pd.concat([yas,boy],axis=1,sort=True)
tc=pd.DataFrame({"age":yas,"len":boy})
tc["age"]["A"]
# Out:
# 25

# %%
tc.index
tc.columns
tc["len"]["D"]
# Out:
# nan

# %%
f=pd.DataFrame(data=np.random.random((1000,5)),columns=["A","B","C","D","E"],index=np.arange(1,1001))
sum(f["A"][:-1])
# Out:
# 515.2221156047065

# %%
f.head()
# Out:
#           A         B         C         D         E
# 1  0.435261  0.426139  0.175953  0.037852  0.881788
# 2  0.033438  0.213426  0.058686  0.462609  0.782421
# 3  0.756182  0.527637  0.393537  0.026211  0.144846
# 4  0.447296  0.668498  0.600556  0.633666  0.580084
# 5  0.402486  0.288840  0.456513  0.234596  0.064085

# %%
d=f.tail()["A"][0:1]
type(d)
d.index
len(d)
# Out:
# 1

# %%
f.head(10)
# Out:
#            A         B         C         D         E
# 1   0.435261  0.426139  0.175953  0.037852  0.881788
# 2   0.033438  0.213426  0.058686  0.462609  0.782421
# 3   0.756182  0.527637  0.393537  0.026211  0.144846
# 4   0.447296  0.668498  0.600556  0.633666  0.580084
# 5   0.402486  0.288840  0.456513  0.234596  0.064085
# 6   0.793311  0.723937  0.178944  0.796363  0.130418
# 7   0.084283  0.416218  0.088091  0.349413  0.312185
# 8   0.621353  0.532449  0.525337  0.444256  0.415467
# 9   0.461178  0.741594  0.805564  0.035975  0.037758
# 10  0.113530  0.734934  0.941445  0.927508  0.069939

# %%
f.tail(10)
# Out:
#              A         B         C         D         E
# 991   0.010937  0.589116  0.260817  0.806950  0.128595
# 992   0.201882  0.098613  0.144522  0.941050  0.378557
# 993   0.077900  0.029160  0.115986  0.372890  0.837195
# 994   0.972032  0.562857  0.275849  0.356267  0.116366
# 995   0.026153  0.841309  0.572544  0.305081  0.443957
# 996   0.986581  0.532081  0.469930  0.290288  0.463596
# 997   0.157915  0.789734  0.809725  0.335691  0.472209
# 998   0.738591  0.250169  0.374081  0.316097  0.240105
# 999   0.440917  0.494998  0.796150  0.784878  0.291438
# 1000  0.620961  0.673784  0.045449  0.077435  0.196155

# %%
f.shape
f.describe()
# Out:
#                  A            B            C            D            E
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.515843     0.507775     0.506385     0.501179     0.496050
# std       0.287126     0.286626     0.294806     0.286855     0.288621
# min       0.001575     0.006509     0.000416     0.000851     0.002037
# 25%       0.279755     0.259906     0.251630     0.245425     0.247999
# 50%       0.522065     0.515390     0.491167     0.501940     0.484602
# 75%       0.756490     0.754069     0.778598     0.755267     0.745581
# max       0.999597     0.999348     0.999920     0.999999     0.999182

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 5 columns):
# A    1000 non-null float64
# B    1000 non-null float64
# C    1000 non-null float64
# D    1000 non-null float64
# E    1000 non-null float64
# dtypes: float64(5)
# memory usage: 46.9 KB

# %%
f.count()
f.sum(axis=0)
f.min()["B"]
f.mean()
f.max()
f.median()
print("Max")
(f.idxmax())
f["A"][876]
f["B"][931]
print("Min")
f.idxmin()

f.max()-f.min()*f.mean()*f.median()
# Out:
# Max
# Min
# A    0.999173
# B    0.997645
# C    0.999817
# D    0.999785
# E    0.998692
# dtype: float64

# %%
m={"ad":["ali","veli","begüm","hilal","umut"],"soyad":["kaya","yurdakul","yıldız","sadık","lori"],"yas":[5,10,25,36,45],"cinsiyet":["E","K","E","E","E"],"maas":[1000,1200,1000,1000,1000]}
t=pd.DataFrame(m)
t.groupby("maas")[["yas"]].mean()
t.pivot_table(index=["cinsiyet","yas"],aggfunc="mean")
# Out:
#               maas
# cinsiyet yas
# E        5    1000
#          25   1000
#          36   1000
#          45   1000
# K        10   1200

# %%
lk=pd.read_csv("2015.csv")
lk
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
#print(lk["Country"])
print(sum(lk["Generosity"]))
lk[["Region","Country"]].head(100)
lk["Freedom"].head(10)
lk[0:-1]["Country"]
lk.loc[np.arange(10),["Country","Region","Family"]]
f=lk.groupby("Region")["Happiness Rank"].max()
type(f)
from matplotlib import pyplot as plt
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.barh(f.index,f.values)
for i, x in enumerate(f.index):
    ax.text(f.values[i],x,str(f.values[i]))

lk.pivot_table(index=["Region","Country"],aggfunc="max")
# Out:
# 37.49269000000002
#                                                    Dystopia Residual  \
# Region                     Country
# Australia and New Zealand  Australia                         2.26646
#                            New Zealand                       2.26425
# Central and Eastern Europe Albania                           1.89894
#                            Armenia                           1.75873
#                            Azerbaijan                        2.00073
#                            Belarus                           2.13090
#                            Bosnia and Herzegovina            2.06367
#                            Bulgaria                          0.89991
#                            Croatia                           2.75414
#                            Czech Republic                    2.67782
#                            Estonia                           1.58782
#                            Georgia                           1.59541
# ...
