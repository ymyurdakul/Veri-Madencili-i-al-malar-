# %%
from sklearn.datasets import load_iris
import numpy as np
from matplotlib import pyplot as plt
y_1=[1,4,5,8,7]
y_2=[5,8,7,3,0]
x_labels=["1","2","3","4","5"]
x_pos=np.arange(5)
plt.barh(x_pos-0.2,y_1,color="r",height=0.2)
plt.barh(x_pos+0.2,y_2,color="c",height=0.2)
lgd=plt.legend(["Kar","Zarar"],)
plt.grid()
plt.xlabel("Ay")
plt.ylabel("Para (1000)")
# Out:
# Text(0, 0.5, 'Para (1000)')

# %%
a=np.arange(10)
b=a*2
plt.barh(a,b)
# Out:
# <BarContainer object of 10 artists>

# %%
x=np.random.randint(150,190,200)
plt.hist(x,5);
plt.grid()

# %%
labels=["elma","armut","yonca"]
x=[1,2,3]
explode=(0,0.2,-0)
plt.pie(x,startangle=15,explode=explode,autopct="%1.1f%%",labels=labels);

# %%
fgr=plt.figure()
fgr.suptitle("Özet")
plt.subplot(221)
x=np.random.rand(100)
 
plt.scatter(x,x**2,marker="<")
plt.title("Kare")
np.corrcoef(x,y)
plt.subplot(222)
plt.title("Küp")
plt.scatter(x,x**3,marker='*')
np.corrcoef(x,x**3)
plt.subplot(223)
plt.title("Küp")
plt.scatter(x,x**4,marker='*',s=80)
np.corrcoef(x,x**3)
plt.subplot(224)
plt.title("Küp")
plt.scatter(x,x**5,marker='*',color="r")
np.corrcoef(x,x**3)
# Out:
# array([[1.        , 0.93075062],
#        [0.93075062, 1.        ]])
