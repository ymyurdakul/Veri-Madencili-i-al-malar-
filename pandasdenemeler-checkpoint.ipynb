# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
wh_2015=pd.read_csv("wh_2015.csv")
wh_2016=pd.read_csv("wh_2016.csv")
wh_2017=pd.read_csv("wh_2016.csv")
x=wh_2015

# %%
x.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
x.shape
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null object
# Region                           158 non-null object
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
x.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
x.count()
# Out:
# Country                          158
# Region                           158
# Happiness Rank                   158
# Happiness Score                  158
# Standard Error                   158
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         158
# Freedom                          158
# Trust (Government Corruption)    158
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
x["Country"].count()
# Out:
# 158

# %%
region_count=len(set(x["Region"]))
country_count=len(set(x["Country"]))
print("Bölge Sayısı {0} Ulke Sayisi {1} ".format(region_count,country_count))
# Out:
# Bölge Sayısı 10 Ulke Sayisi 158

# %% [markdown]
# # Bölgelere göre özgürlük ortalaması

# %%
x.groupby("Region")["Freedom"].mean()
# Out:
# Region
# Australia and New Zealand          0.645310
# Central and Eastern Europe         0.358269
# Eastern Asia                       0.462490
# Latin America and Caribbean        0.501740
# Middle East and Northern Africa    0.361751
# North America                      0.589505
# Southeastern Asia                  0.557104
# Southern Asia                      0.373337
# Sub-Saharan Africa                 0.365944
# Western Europe                     0.549926
# Name: Freedom, dtype: float64

# %% [markdown]
# # Bölgelere göre kişi başı düşen milli gelir

# %%
x.columns
t=x.groupby("Region")["Economy (GDP per Capita)"].mean()
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.barh(t.index,t.values)
for i,v in enumerate(t.values):
    ax.text(v,i,str("{0:.2f}".format(v)))

# %%
x.columns
t=x.groupby("Country")["Happiness Rank"].mean()
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.pie(t.values,autopct="%.2f%%",labels=set(x["Country"]));

# %%
x.pivot_table(index=["Region","Country"])["Happiness Rank"]
# Out:
# Region                      Country
# Australia and New Zealand   Australia                  10
#                             New Zealand                 9
# Central and Eastern Europe  Albania                    95
#                             Armenia                   127
#                             Azerbaijan                 80
#                             Belarus                    59
#                             Bosnia and Herzegovina     96
#                             Bulgaria                  134
#                             Croatia                    62
#                             Czech Republic             31
#                             Estonia                    73
#                             Georgia                   130
#                             Hungary                   104
#                             Kazakhstan                 54
#                             Kosovo                     69
#                             Kyrgyzstan                 77
# ...

# %%
x[100:200].head(10)
# Out:
#                      Country                           Region  Happiness Rank  \
# 100                Swaziland               Sub-Saharan Africa             101
# 101                   Greece                   Western Europe             102
# 102                  Lebanon  Middle East and Northern Africa             103
# 103                  Hungary       Central and Eastern Europe             104
# 104                 Honduras      Latin America and Caribbean             105
# 105               Tajikistan       Central and Eastern Europe             106
# 106                  Tunisia  Middle East and Northern Africa             107
# 107  Palestinian Territories  Middle East and Northern Africa             108
# 108               Bangladesh                    Southern Asia             109
# 109                     Iran  Middle East and Northern Africa             110
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
x.loc[[1,3,100],["Country","Happiness Rank"]]
# Out:
#        Country  Happiness Rank
# 1      Iceland               2
# 3       Norway               4
# 100  Swaziland             101

# %%
x.iloc[0:10,3:]
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
# 5            7.406         0.03140                   1.29025  1.31826
# 6            7.378         0.02799                   1.32944  1.28017
# 7            7.364         0.03157                   1.33171  1.28907
# 8            7.286         0.03371                   1.25018  1.31967
# 9            7.284         0.04083                   1.33358  1.30923
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# ...

# %%
gh=(wh_2015[x["Country"]=="Turkey"])["Family"]
fx=wh_2016[wh_2016["Country"]=="Turkey"]["Family"]
fd=wh_2017[wh_2017["Country"]=="Turkey"]["Family"]


x.drop(index=range(2,x.shape[0]),axis=0)
x.head()
x.drop(labels=["Country","Region","Freedom","Generosity","Family"],axis=1)

#
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# 5                 6            7.406         0.03140
# 6                 7            7.378         0.02799
# 7                 8            7.364         0.03157
# 8                 9            7.286         0.03371
# 9                10            7.284         0.04083
# 10               11            7.278         0.03470
# 11               12            7.226         0.04454
# 12               13            7.200         0.03751
# 13               14            7.187         0.04176
# 14               15            7.119         0.03839
# 15               16            6.983         0.04076
# 16               17            6.946         0.03499
# ...

# %%
x.sort_values(by="Freedom",ascending=False).head()
x[(x["Happiness Rank"]<4)&(x["Family"]>.8)].head().sort_values(by="Family",ascending=False)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 0  Switzerland  Western Europe               1            7.587
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 0         0.03411                   1.39651  1.34951
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 0                   0.94143  0.66557                        0.41978
#
#    Generosity  Dystopia Residual
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 0     0.29678            2.51738

# %%
x.rank(ascending=False).head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0     23.0    11.0           158.0              1.0           139.0
# 1    100.0    11.0           157.0              2.0            55.0
# 2    121.0    11.0           156.0              3.0           142.0
# 3     53.0    11.0           155.0              4.0           106.0
# 4    134.0    78.5           154.0              5.0           132.0
#
#    Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       7.0     4.0                       9.0      2.0
# 1                      22.0     1.0                       7.0     15.0
# 2                      19.0     3.0                      30.0      7.0
# 3                       5.0     6.0                      26.0      1.0
# 4                      18.0     7.0                      18.0     13.0
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                            7.0        43.0               33.0
# ...

# %%
x[x["Country"]=="Turkey"]
# Out:
#    Country                           Region  Happiness Rank  Happiness Score  \
# 75  Turkey  Middle East and Northern Africa              76            5.332
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 75         0.03864                   1.06098  0.94632
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 75                   0.73172  0.22815                        0.15746
#
#     Generosity  Dystopia Residual
# 75     0.12253            2.08528

# %%
turkey=x[x["Country"]=="Turkey"]["Family"]
ıraq=x[x["Country"]=="Iraq"]["Family"]
turkey+ıraq
yas=pd.Series({"a":12,"b":21,"c":45})
kilo=pd.Series({"a":52,"b":65})
yas+kilo
# Out:
# a    64.0
# b    86.0
# c     NaN
# dtype: float64

# %%
x["F Score"]=x.apply(lambda satir:satir["Family"]+satir["Freedom"],axis=1)
x["T Score"]=x.apply(lambda sutun:sutun.max())

# %%
x[["Family","Freedom"]].plot(subplots=True,kind="line")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002EBC67D49B0>,
# ...
#       dtype=object)

# %%
x[["Family","Freedom","F Score"]].hist(bins=20)
x.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'F Score', 'T Score'],
#       dtype='object')

# %%
x.plot(kind="scatter",x="Freedom",y="Family")

# %%
x.plot(kind="line",y="Family")
